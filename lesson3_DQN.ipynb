# %%
'''
【作业3评分标准】（需要保留notebook上每个cell运行之后的log信息）：
1、完全没有log信息，59分
2、完成部分函数的编写，有部分log信息，但代码运行失败，70分
3、代码运行成功，但test_reward无法收敛（所有分数均低于-140），80分
4、代码运行成功，分数有上涨趋势，且最终输出的test_reward收敛至[-120, -140]之间，90分
5、代码运行成功，分数有上涨趋势，且最终输出的test_reward收敛至大于-120，100分

【作业3满分标准补充说明】
1、最后10个分数一半以上大于-120，100分
2、如果最后10个分数表现不好，但是最近50个分数大部分都大于-120，100分
3、其他情况酌情给分
'''

# %%
import parl
from parl import layers
import paddle.fluid as fluid
import copy
import numpy as np
import os
import gym
from parl.utils import logger
from parl.algorithms import DQN
import random
import collections

# %%
LEARN_FREQ = 5 # 训练频率，不需要每一个step都learn，攒一些新增经验后再learn，提高效率
MEMORY_SIZE= int(20000)    # replay memory的大小，越大越占用内存
MEMORY_WARMUP_SIZE = 200   # replay_memory 里需要预存一些经验数据，再从里面sample一个batch的经验让agent去learn
BATCH_SIZE = 64   # 每次给agent learn的数据数量，从replay memory随机里sample一批数据出来
GAMMA = 0.99 # reward 的衰减因子，一般取 0.9 到 0.999 不等

LEARNING_RATE = 5e-4 # 学习率

# %%
class Model(parl.Model):
    def __init__(self, act_dim):
        hidden_size = 256
        self.net1 = layers.fc(size=hidden_size, act='relu')
        self.net2 = layers.fc(size=hidden_size, act='relu')
        self.net3 = layers.fc(size=hidden_size, act='relu')
        self.net4 = layers.fc(size=hidden_size, act='relu')
        self.net5 = layers.fc(size=act_dim, act=None)
    def value(self, obs):
        hidden1  = self.net1(obs)
        hidden2  = self.net2(hidden1)
        hidden3  = self.net3(hidden2)
        hidden4  = self.net4(hidden3)
        Q_value  = self.net5(hidden4)
        return Q_value

# %%
class Agent(parl.Agent):
    def __init__(self,
                 algorithm,
                 obs_dim,
                 act_dim,
                 e_greed=0.1,
                 e_greed_decrement=0):
        assert isinstance(obs_dim, int)
        assert isinstance(act_dim, int)
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        super(Agent, self).__init__(algorithm)

        self.global_step = 0
        self.update_target_steps = 200  # 每隔200个training steps再把model的参数复制到target_model中

        self.e_greed = e_greed  # 有一定概率随机选取动作，探索
        self.e_greed_decrement = e_greed_decrement  # 随着训练逐步收敛，探索的程度慢慢降低

    def build_program(self):
        self.pred_program = fluid.Program()
        self.learn_program = fluid.Program()

        with fluid.program_guard(self.pred_program):  # 搭建计算图用于 预测动作，定义输入输出变量
            obs = layers.data(
                name='obs', shape=[self.obs_dim], dtype='float32')
            self.value = self.alg.predict(obs)

        with fluid.program_guard(self.learn_program):  # 搭建计算图用于 更新Q网络，定义输入输出变量
            obs = layers.data(
                name='obs', shape=[self.obs_dim], dtype='float32')
            action = layers.data(name='act', shape=[1], dtype='int32')
            reward = layers.data(name='reward', shape=[], dtype='float32')
            next_obs = layers.data(
                name='next_obs', shape=[self.obs_dim], dtype='float32')
            terminal = layers.data(name='terminal', shape=[], dtype='bool')
            self.cost = self.alg.learn(obs, action, reward, next_obs, terminal)

    def sample(self, obs):
        sample = np.random.rand()  # 产生0~1之间的小数
        if sample < self.e_greed:
            act = np.random.randint(self.act_dim)  # 探索：每个动作都有概率被选择
        else:
            act = self.predict(obs)  # 选择最优动作
        self.e_greed = max(
            0.001, self.e_greed - self.e_greed_decrement)  # 随着训练逐步收敛，探索的程度慢慢降低
        return act

    def predict(self, obs):  # 选择最优动作
        obs = np.expand_dims(obs, axis=0)
        pred_Q = self.fluid_executor.run(
            self.pred_program,
            feed={'obs': obs.astype('float32')},
            fetch_list=[self.value])[0]
        pred_Q = np.squeeze(pred_Q, axis=0)
        act = np.argmax(pred_Q)  # 选择Q最大的下标，即对应的动作
        return act

    def learn(self, obs, act, reward, next_obs, terminal):
        # 每隔200个training steps同步一次model和target_model的参数
        if self.global_step % self.update_target_steps == 0:
            self.alg.sync_target()
        self.global_step += 1

        act = np.expand_dims(act, -1)
        feed = {
            'obs': obs.astype('float32'),
            'act': act.astype('int32'),
            'reward': reward,
            'next_obs': next_obs.astype('float32'),
            'terminal': terminal
        }
        cost = self.fluid_executor.run(
            self.learn_program, feed=feed, fetch_list=[self.cost])[0]  # 训练一次网络
        return cost

# %%
class ReplayMemory(object):
    def __init__(self, max_size):
        self.buffer = collections.deque(maxlen=max_size)
    def append(self, exp):
        self.buffer.append(exp)
    def sample(self, batch_size):
        mini_batch = random.sample(self.buffer, batch_size)
        obs_batch, action_batch, reward_batch, next_obs_batch, done_batch = [], [], [], [], []

        for experience in mini_batch:
            s, a, r, s_p, done = experience
            obs_batch.append(s)
            action_batch.append(a)
            reward_batch.append(r)
            next_obs_batch.append(s_p)
            done_batch.append(done)
        return np.array(obs_batch).astype('float32'), \
            np.array(action_batch).astype('float32'), np.array(reward_batch).astype('float32'),\
            np.array(next_obs_batch).astype('float32'), np.array(done_batch).astype('float32')
    def __len__(self):
        return len(self.buffer)

# %%
# 训练一个episode
def run_episode(env, agent, rpm):
    total_reward = 0
    obs = env.reset()
    step = 0
    while True:
        step += 1
        action = agent.sample(obs)  # 采样动作，所有动作都有概率被尝试到
        next_obs, reward, done, _ = env.step(action)
        rpm.append((obs, action, reward, next_obs, done))

        # train model
        if (len(rpm) > MEMORY_WARMUP_SIZE) and (step % LEARN_FREQ == 0):
            (batch_obs, batch_action, batch_reward, batch_next_obs,
             batch_done) = rpm.sample(BATCH_SIZE)
            train_loss = agent.learn(batch_obs, batch_action, batch_reward,
                                     batch_next_obs,
                                     batch_done)  # s,a,r,s',done

        total_reward += reward
        obs = next_obs
        if done:
            break
    return total_reward

# 评估 agent, 跑 5 个episode，总reward求平均
def evaluate(env, agent, render=False):
    eval_reward = []
    for i in range(5):
        obs = env.reset()
        episode_reward = 0
        while True:
            action = agent.predict(obs)  # 预测动作，只选最优动作
            obs, reward, done, _ = env.step(action)
            episode_reward += reward
            if render:
                env.render()
            if done:
                break
        eval_reward.append(episode_reward)
    return np.mean(eval_reward)

# %%
# 创建环境
env = gym.make('MountainCar-v0')
action_dim = env.action_space.n  # MountainCar-v0: 3
obs_shape  = env.observation_space.shape  # MountainCar-v0: (2,)

# 创建经验池
rpm = ReplayMemory(MEMORY_SIZE)  # DQN的经验回放池

# 根据parl框架构建agent
# 4. 请参考课堂Demo，嵌套Model, DQN, Agent构建 agent
model = Model(act_dim=action_dim)
algorithm = DQN(model, act_dim=action_dim, gamma=GAMMA, lr=LEARNING_RATE)
agent = Agent(algorithm,obs_dim=obs_shape[0],act_dim=action_dim,e_greed=0.2,  e_greed_decrement=1e-6)  


# 加载模型
# save_path = './dqn_model.ckpt'
# agent.restore(save_path)

# 先往经验池里存一些数据，避免最开始训练的时候样本丰富度不够
while len(rpm) < MEMORY_WARMUP_SIZE:
    run_episode(env, agent, rpm)

max_episode = 20000

# 开始训练
episode = 0
while episode < max_episode:  # 训练max_episode个回合，test部分不计算入episode数量
    # train part
    for i in range(0, 50):
        total_reward = run_episode(env, agent, rpm)
        episode += 1

    # test part
    eval_reward = evaluate(env, agent, render=False)  # render=True 查看显示效果
    logger.info('episode:{}    e_greed:{}   test_reward:{}'.format(
        episode, agent.e_greed, eval_reward))

# 训练结束，保存模型
save_path = './model_dir/dqn_model.ckpt'
agent.save(save_path)
# Out:
# [06-26 18:41:54 MainThread @machine_info.py:86] nvidia-smi -L found gpu count: 1
# [06-26 18:41:54 MainThread @machine_info.py:86] nvidia-smi -L found gpu count: 1
# [06-26 18:41:54 MainThread @machine_info.py:86] nvidia-smi -L found gpu count: 1
# [06-26 18:42:30 MainThread @<ipython-input-8-15532eada1ec>:37] episode:50    e_greed:0.18990499999998992   test_reward:-200.0
# [06-26 18:43:06 MainThread @<ipython-input-8-15532eada1ec>:37] episode:100    e_greed:0.18014799999998016   test_reward:-200.0
# [06-26 18:43:43 MainThread @<ipython-input-8-15532eada1ec>:37] episode:150    e_greed:0.17025399999997026   test_reward:-200.0
# [06-26 18:44:19 MainThread @<ipython-input-8-15532eada1ec>:37] episode:200    e_greed:0.16032699999996033   test_reward:-200.0
# [06-26 18:44:55 MainThread @<ipython-input-8-15532eada1ec>:37] episode:250    e_greed:0.15033899999995035   test_reward:-200.0
# [06-26 18:45:31 MainThread @<ipython-input-8-15532eada1ec>:37] episode:300    e_greed:0.1404029999999404   test_reward:-200.0
# [06-26 18:46:07 MainThread @<ipython-input-8-15532eada1ec>:37] episode:350    e_greed:0.13043599999993044   test_reward:-200.0
# [06-26 18:46:44 MainThread @<ipython-input-8-15532eada1ec>:37] episode:400    e_greed:0.12053699999992054   test_reward:-200.0
# [06-26 18:47:18 MainThread @<ipython-input-8-15532eada1ec>:37] episode:450    e_greed:0.1110919999999111   test_reward:-156.4
# [06-26 18:47:53 MainThread @<ipython-input-8-15532eada1ec>:37] episode:500    e_greed:0.10187199999990187   test_reward:-200.0
# [06-26 18:48:28 MainThread @<ipython-input-8-15532eada1ec>:37] episode:550    e_greed:0.09247599999989248   test_reward:-200.0
# [06-26 18:49:05 MainThread @<ipython-input-8-15532eada1ec>:37] episode:600    e_greed:0.08272699999988273   test_reward:-200.0
# [06-26 18:49:41 MainThread @<ipython-input-8-15532eada1ec>:37] episode:650    e_greed:0.0732069999998732   test_reward:-200.0
# [06-26 18:50:14 MainThread @<ipython-input-8-15532eada1ec>:37] episode:700    e_greed:0.06452099999986452   test_reward:-200.0
# [06-26 18:50:44 MainThread @<ipython-input-8-15532eada1ec>:37] episode:750    e_greed:0.05663899999985664   test_reward:-200.0
# [06-26 18:51:14 MainThread @<ipython-input-8-15532eada1ec>:37] episode:800    e_greed:0.0487999999998488   test_reward:-135.2
# [06-26 18:51:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:850    e_greed:0.04252499999984252   test_reward:-127.8
# [06-26 18:52:05 MainThread @<ipython-input-8-15532eada1ec>:37] episode:900    e_greed:0.035698999999835695   test_reward:-197.6
# [06-26 18:52:37 MainThread @<ipython-input-8-15532eada1ec>:37] episode:950    e_greed:0.027500999999827497   test_reward:-166.2
# [06-26 18:53:08 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1000    e_greed:0.01973499999981973   test_reward:-145.8
# [06-26 18:53:34 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1050    e_greed:0.012967999999817573   test_reward:-123.0
# [06-26 18:53:59 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1100    e_greed:0.0066609999998212075   test_reward:-93.6
# [06-26 18:54:24 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1150    e_greed:0.001   test_reward:-143.8
# [06-26 18:54:47 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1200    e_greed:0.001   test_reward:-131.0
# [06-26 18:55:09 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1250    e_greed:0.001   test_reward:-97.2
# [06-26 18:55:30 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1300    e_greed:0.001   test_reward:-111.8
# [06-26 18:55:50 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1350    e_greed:0.001   test_reward:-100.4
# [06-26 18:56:10 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1400    e_greed:0.001   test_reward:-106.4
# [06-26 18:56:30 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1450    e_greed:0.001   test_reward:-102.4
# [06-26 18:56:49 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1500    e_greed:0.001   test_reward:-103.8
# [06-26 18:57:09 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1550    e_greed:0.001   test_reward:-103.6
# [06-26 18:57:28 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1600    e_greed:0.001   test_reward:-101.0
# [06-26 18:57:48 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1650    e_greed:0.001   test_reward:-92.8
# [06-26 18:58:07 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1700    e_greed:0.001   test_reward:-100.0
# [06-26 18:58:27 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1750    e_greed:0.001   test_reward:-96.6
# [06-26 18:58:46 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1800    e_greed:0.001   test_reward:-103.8
# [06-26 18:59:07 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1850    e_greed:0.001   test_reward:-107.4
# [06-26 18:59:27 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1900    e_greed:0.001   test_reward:-99.6
# [06-26 18:59:46 MainThread @<ipython-input-8-15532eada1ec>:37] episode:1950    e_greed:0.001   test_reward:-101.4
# [06-26 19:00:06 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2000    e_greed:0.001   test_reward:-96.4
# [06-26 19:00:25 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2050    e_greed:0.001   test_reward:-101.2
# [06-26 19:00:47 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2100    e_greed:0.001   test_reward:-145.0
# [06-26 19:01:08 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2150    e_greed:0.001   test_reward:-139.8
# [06-26 19:01:30 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2200    e_greed:0.001   test_reward:-147.4
# [06-26 19:01:53 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2250    e_greed:0.001   test_reward:-122.6
# [06-26 19:02:14 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2300    e_greed:0.001   test_reward:-97.0
# [06-26 19:02:35 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2350    e_greed:0.001   test_reward:-105.2
# [06-26 19:02:56 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2400    e_greed:0.001   test_reward:-95.8
# [06-26 19:03:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2450    e_greed:0.001   test_reward:-103.2
# [06-26 19:03:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2500    e_greed:0.001   test_reward:-98.2
# [06-26 19:03:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2550    e_greed:0.001   test_reward:-93.4
# [06-26 19:04:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2600    e_greed:0.001   test_reward:-101.6
# [06-26 19:04:37 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2650    e_greed:0.001   test_reward:-102.2
# [06-26 19:04:56 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2700    e_greed:0.001   test_reward:-99.2
# [06-26 19:05:15 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2750    e_greed:0.001   test_reward:-97.2
# [06-26 19:05:34 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2800    e_greed:0.001   test_reward:-99.0
# [06-26 19:05:54 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2850    e_greed:0.001   test_reward:-102.8
# [06-26 19:06:13 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2900    e_greed:0.001   test_reward:-103.2
# [06-26 19:06:32 MainThread @<ipython-input-8-15532eada1ec>:37] episode:2950    e_greed:0.001   test_reward:-97.2
# [06-26 19:06:54 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3000    e_greed:0.001   test_reward:-134.6
# [06-26 19:07:15 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3050    e_greed:0.001   test_reward:-113.0
# [06-26 19:07:37 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3100    e_greed:0.001   test_reward:-103.4
# [06-26 19:07:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3150    e_greed:0.001   test_reward:-144.6
# [06-26 19:08:16 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3200    e_greed:0.001   test_reward:-101.0
# [06-26 19:08:37 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3250    e_greed:0.001   test_reward:-99.0
# [06-26 19:08:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3300    e_greed:0.001   test_reward:-94.4
# [06-26 19:09:18 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3350    e_greed:0.001   test_reward:-102.2
# [06-26 19:09:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3400    e_greed:0.001   test_reward:-100.6
# [06-26 19:09:58 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3450    e_greed:0.001   test_reward:-99.4
# [06-26 19:10:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3500    e_greed:0.001   test_reward:-103.4
# [06-26 19:10:37 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3550    e_greed:0.001   test_reward:-100.0
# [06-26 19:10:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3600    e_greed:0.001   test_reward:-102.0
# [06-26 19:11:18 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3650    e_greed:0.001   test_reward:-104.8
# [06-26 19:11:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3700    e_greed:0.001   test_reward:-103.0
# [06-26 19:11:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3750    e_greed:0.001   test_reward:-108.8
# [06-26 19:12:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3800    e_greed:0.001   test_reward:-104.0
# [06-26 19:12:39 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3850    e_greed:0.001   test_reward:-108.4
# [06-26 19:13:00 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3900    e_greed:0.001   test_reward:-102.6
# [06-26 19:13:19 MainThread @<ipython-input-8-15532eada1ec>:37] episode:3950    e_greed:0.001   test_reward:-102.4
# [06-26 19:13:39 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4000    e_greed:0.001   test_reward:-101.6
# [06-26 19:13:59 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4050    e_greed:0.001   test_reward:-103.0
# [06-26 19:14:18 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4100    e_greed:0.001   test_reward:-98.6
# [06-26 19:14:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4150    e_greed:0.001   test_reward:-98.8
# [06-26 19:14:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4200    e_greed:0.001   test_reward:-103.6
# [06-26 19:15:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4250    e_greed:0.001   test_reward:-99.2
# [06-26 19:15:37 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4300    e_greed:0.001   test_reward:-101.8
# [06-26 19:15:58 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4350    e_greed:0.001   test_reward:-96.8
# [06-26 19:16:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4400    e_greed:0.001   test_reward:-99.4
# [06-26 19:16:37 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4450    e_greed:0.001   test_reward:-143.0
# [06-26 19:16:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4500    e_greed:0.001   test_reward:-98.2
# [06-26 19:17:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4550    e_greed:0.001   test_reward:-94.4
# [06-26 19:17:36 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4600    e_greed:0.001   test_reward:-98.6
# [06-26 19:17:59 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4650    e_greed:0.001   test_reward:-110.8
# [06-26 19:18:20 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4700    e_greed:0.001   test_reward:-105.8
# [06-26 19:18:42 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4750    e_greed:0.001   test_reward:-108.6
# [06-26 19:19:02 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4800    e_greed:0.001   test_reward:-96.2
# [06-26 19:19:22 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4850    e_greed:0.001   test_reward:-97.8
# [06-26 19:19:42 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4900    e_greed:0.001   test_reward:-100.4
# [06-26 19:20:02 MainThread @<ipython-input-8-15532eada1ec>:37] episode:4950    e_greed:0.001   test_reward:-100.6
# [06-26 19:20:21 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5000    e_greed:0.001   test_reward:-98.6
# [06-26 19:20:41 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5050    e_greed:0.001   test_reward:-103.2
# [06-26 19:21:01 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5100    e_greed:0.001   test_reward:-100.6
# [06-26 19:21:20 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5150    e_greed:0.001   test_reward:-96.8
# [06-26 19:21:39 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5200    e_greed:0.001   test_reward:-99.4
# [06-26 19:21:59 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5250    e_greed:0.001   test_reward:-100.2
# [06-26 19:22:19 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5300    e_greed:0.001   test_reward:-100.6
# [06-26 19:22:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5350    e_greed:0.001   test_reward:-103.0
# [06-26 19:22:58 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5400    e_greed:0.001   test_reward:-102.4
# [06-26 19:23:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5450    e_greed:0.001   test_reward:-96.4
# [06-26 19:23:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5500    e_greed:0.001   test_reward:-100.4
# [06-26 19:23:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5550    e_greed:0.001   test_reward:-95.4
# [06-26 19:24:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5600    e_greed:0.001   test_reward:-102.0
# [06-26 19:24:37 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5650    e_greed:0.001   test_reward:-99.8
# [06-26 19:24:56 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5700    e_greed:0.001   test_reward:-102.6
# [06-26 19:25:16 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5750    e_greed:0.001   test_reward:-103.4
# [06-26 19:25:36 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5800    e_greed:0.001   test_reward:-96.4
# [06-26 19:25:56 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5850    e_greed:0.001   test_reward:-101.4
# [06-26 19:26:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5900    e_greed:0.001   test_reward:-100.2
# [06-26 19:26:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:5950    e_greed:0.001   test_reward:-90.8
# [06-26 19:26:59 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6000    e_greed:0.001   test_reward:-97.4
# [06-26 19:27:19 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6050    e_greed:0.001   test_reward:-112.0
# [06-26 19:27:39 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6100    e_greed:0.001   test_reward:-104.6
# [06-26 19:27:59 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6150    e_greed:0.001   test_reward:-91.6
# [06-26 19:28:21 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6200    e_greed:0.001   test_reward:-99.0
# [06-26 19:28:41 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6250    e_greed:0.001   test_reward:-98.6
# [06-26 19:29:01 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6300    e_greed:0.001   test_reward:-100.2
# [06-26 19:29:20 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6350    e_greed:0.001   test_reward:-97.2
# [06-26 19:29:40 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6400    e_greed:0.001   test_reward:-99.6
# [06-26 19:30:00 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6450    e_greed:0.001   test_reward:-95.6
# [06-26 19:30:19 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6500    e_greed:0.001   test_reward:-96.6
# [06-26 19:30:39 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6550    e_greed:0.001   test_reward:-93.0
# [06-26 19:30:58 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6600    e_greed:0.001   test_reward:-101.0
# [06-26 19:31:18 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6650    e_greed:0.001   test_reward:-101.4
# [06-26 19:31:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6700    e_greed:0.001   test_reward:-100.4
# [06-26 19:31:58 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6750    e_greed:0.001   test_reward:-103.2
# [06-26 19:32:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6800    e_greed:0.001   test_reward:-96.6
# [06-26 19:32:39 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6850    e_greed:0.001   test_reward:-118.6
# [06-26 19:32:58 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6900    e_greed:0.001   test_reward:-102.4
# [06-26 19:33:19 MainThread @<ipython-input-8-15532eada1ec>:37] episode:6950    e_greed:0.001   test_reward:-93.4
# [06-26 19:33:39 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7000    e_greed:0.001   test_reward:-99.2
# [06-26 19:33:59 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7050    e_greed:0.001   test_reward:-96.2
# [06-26 19:34:18 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7100    e_greed:0.001   test_reward:-101.2
# [06-26 19:34:37 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7150    e_greed:0.001   test_reward:-97.6
# [06-26 19:34:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7200    e_greed:0.001   test_reward:-90.0
# [06-26 19:35:16 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7250    e_greed:0.001   test_reward:-106.0
# [06-26 19:35:36 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7300    e_greed:0.001   test_reward:-96.6
# [06-26 19:35:55 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7350    e_greed:0.001   test_reward:-102.8
# [06-26 19:36:15 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7400    e_greed:0.001   test_reward:-102.6
# [06-26 19:36:35 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7450    e_greed:0.001   test_reward:-100.6
# [06-26 19:36:56 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7500    e_greed:0.001   test_reward:-96.0
# [06-26 19:37:16 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7550    e_greed:0.001   test_reward:-98.6
# [06-26 19:37:35 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7600    e_greed:0.001   test_reward:-102.8
# [06-26 19:37:55 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7650    e_greed:0.001   test_reward:-101.8
# [06-26 19:38:14 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7700    e_greed:0.001   test_reward:-95.8
# [06-26 19:38:34 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7750    e_greed:0.001   test_reward:-99.6
# [06-26 19:38:53 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7800    e_greed:0.001   test_reward:-95.0
# [06-26 19:39:12 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7850    e_greed:0.001   test_reward:-104.0
# [06-26 19:39:33 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7900    e_greed:0.001   test_reward:-100.8
# [06-26 19:39:54 MainThread @<ipython-input-8-15532eada1ec>:37] episode:7950    e_greed:0.001   test_reward:-110.2
# [06-26 19:40:14 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8000    e_greed:0.001   test_reward:-101.6
# [06-26 19:40:35 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8050    e_greed:0.001   test_reward:-107.0
# [06-26 19:40:56 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8100    e_greed:0.001   test_reward:-97.0
# [06-26 19:41:16 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8150    e_greed:0.001   test_reward:-104.2
# [06-26 19:41:36 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8200    e_greed:0.001   test_reward:-119.8
# [06-26 19:41:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8250    e_greed:0.001   test_reward:-103.4
# [06-26 19:42:19 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8300    e_greed:0.001   test_reward:-117.8
# [06-26 19:42:44 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8350    e_greed:0.001   test_reward:-125.4
# [06-26 19:43:06 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8400    e_greed:0.001   test_reward:-104.0
# [06-26 19:43:30 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8450    e_greed:0.001   test_reward:-100.0
# [06-26 19:43:52 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8500    e_greed:0.001   test_reward:-106.4
# [06-26 19:44:12 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8550    e_greed:0.001   test_reward:-110.8
# [06-26 19:44:32 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8600    e_greed:0.001   test_reward:-99.4
# [06-26 19:44:52 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8650    e_greed:0.001   test_reward:-103.2
# [06-26 19:45:12 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8700    e_greed:0.001   test_reward:-105.6
# [06-26 19:45:33 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8750    e_greed:0.001   test_reward:-109.0
# [06-26 19:45:54 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8800    e_greed:0.001   test_reward:-93.8
# [06-26 19:46:14 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8850    e_greed:0.001   test_reward:-99.2
# [06-26 19:46:34 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8900    e_greed:0.001   test_reward:-101.2
# [06-26 19:46:53 MainThread @<ipython-input-8-15532eada1ec>:37] episode:8950    e_greed:0.001   test_reward:-92.2
# [06-26 19:47:13 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9000    e_greed:0.001   test_reward:-96.8
# [06-26 19:47:33 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9050    e_greed:0.001   test_reward:-102.2
# [06-26 19:47:54 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9100    e_greed:0.001   test_reward:-94.2
# [06-26 19:48:13 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9150    e_greed:0.001   test_reward:-103.0
# [06-26 19:48:33 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9200    e_greed:0.001   test_reward:-100.8
# [06-26 19:48:53 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9250    e_greed:0.001   test_reward:-103.6
# [06-26 19:49:12 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9300    e_greed:0.001   test_reward:-98.2
# [06-26 19:49:32 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9350    e_greed:0.001   test_reward:-96.6
# [06-26 19:49:52 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9400    e_greed:0.001   test_reward:-101.0
# [06-26 19:50:13 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9450    e_greed:0.001   test_reward:-100.6
# [06-26 19:50:33 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9500    e_greed:0.001   test_reward:-97.4
# [06-26 19:50:53 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9550    e_greed:0.001   test_reward:-101.4
# [06-26 19:51:13 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9600    e_greed:0.001   test_reward:-99.4
# [06-26 19:51:32 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9650    e_greed:0.001   test_reward:-99.4
# [06-26 19:51:52 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9700    e_greed:0.001   test_reward:-96.2
# [06-26 19:52:11 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9750    e_greed:0.001   test_reward:-101.0
# [06-26 19:52:31 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9800    e_greed:0.001   test_reward:-103.2
# [06-26 19:52:51 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9850    e_greed:0.001   test_reward:-100.4
# [06-26 19:53:11 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9900    e_greed:0.001   test_reward:-98.4
# [06-26 19:53:32 MainThread @<ipython-input-8-15532eada1ec>:37] episode:9950    e_greed:0.001   test_reward:-128.4
# [06-26 19:53:53 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10000    e_greed:0.001   test_reward:-99.4
# [06-26 19:54:13 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10050    e_greed:0.001   test_reward:-90.2
# [06-26 19:54:33 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10100    e_greed:0.001   test_reward:-97.6
# [06-26 19:54:52 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10150    e_greed:0.001   test_reward:-102.0
# [06-26 19:55:12 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10200    e_greed:0.001   test_reward:-102.4
# [06-26 19:55:33 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10250    e_greed:0.001   test_reward:-113.4
# [06-26 19:55:53 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10300    e_greed:0.001   test_reward:-97.6
# [06-26 19:56:13 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10350    e_greed:0.001   test_reward:-96.4
# [06-26 19:56:32 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10400    e_greed:0.001   test_reward:-103.6
# [06-26 19:56:52 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10450    e_greed:0.001   test_reward:-103.2
# [06-26 19:57:12 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10500    e_greed:0.001   test_reward:-99.2
# [06-26 19:57:32 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10550    e_greed:0.001   test_reward:-103.2
# [06-26 19:57:51 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10600    e_greed:0.001   test_reward:-97.4
# [06-26 19:58:11 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10650    e_greed:0.001   test_reward:-101.8
# [06-26 19:58:31 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10700    e_greed:0.001   test_reward:-100.4
# [06-26 19:58:53 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10750    e_greed:0.001   test_reward:-135.2
# [06-26 19:59:14 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10800    e_greed:0.001   test_reward:-100.8
# [06-26 19:59:35 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10850    e_greed:0.001   test_reward:-102.0
# [06-26 19:59:56 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10900    e_greed:0.001   test_reward:-105.6
# [06-26 20:00:16 MainThread @<ipython-input-8-15532eada1ec>:37] episode:10950    e_greed:0.001   test_reward:-97.4
# [06-26 20:00:36 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11000    e_greed:0.001   test_reward:-102.4
# [06-26 20:00:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11050    e_greed:0.001   test_reward:-110.2
# [06-26 20:01:17 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11100    e_greed:0.001   test_reward:-104.2
# [06-26 20:01:37 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11150    e_greed:0.001   test_reward:-97.2
# [06-26 20:01:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11200    e_greed:0.001   test_reward:-118.4
# [06-26 20:02:18 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11250    e_greed:0.001   test_reward:-99.8
# [06-26 20:02:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11300    e_greed:0.001   test_reward:-96.0
# [06-26 20:02:58 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11350    e_greed:0.001   test_reward:-94.2
# [06-26 20:03:18 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11400    e_greed:0.001   test_reward:-100.0
# [06-26 20:03:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11450    e_greed:0.001   test_reward:-100.0
# [06-26 20:03:58 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11500    e_greed:0.001   test_reward:-100.4
# [06-26 20:04:18 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11550    e_greed:0.001   test_reward:-104.0
# [06-26 20:04:37 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11600    e_greed:0.001   test_reward:-99.6
# [06-26 20:04:57 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11650    e_greed:0.001   test_reward:-101.0
# [06-26 20:05:18 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11700    e_greed:0.001   test_reward:-102.4
# [06-26 20:05:38 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11750    e_greed:0.001   test_reward:-98.4
# [06-26 20:05:58 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11800    e_greed:0.001   test_reward:-97.0
# [06-26 20:06:21 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11850    e_greed:0.001   test_reward:-140.2
# [06-26 20:06:41 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11900    e_greed:0.001   test_reward:-99.8
# [06-26 20:07:00 MainThread @<ipython-input-8-15532eada1ec>:37] episode:11950    e_greed:0.001   test_reward:-93.0
# [06-26 20:07:20 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12000    e_greed:0.001   test_reward:-95.8
# [06-26 20:07:39 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12050    e_greed:0.001   test_reward:-97.2
# [06-26 20:08:00 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12100    e_greed:0.001   test_reward:-96.2
# [06-26 20:08:21 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12150    e_greed:0.001   test_reward:-103.6
# [06-26 20:08:43 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12200    e_greed:0.001   test_reward:-114.2
# [06-26 20:09:04 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12250    e_greed:0.001   test_reward:-99.4
# [06-26 20:09:23 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12300    e_greed:0.001   test_reward:-99.4
# [06-26 20:09:43 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12350    e_greed:0.001   test_reward:-103.8
# [06-26 20:10:03 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12400    e_greed:0.001   test_reward:-103.6
# [06-26 20:10:23 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12450    e_greed:0.001   test_reward:-96.2
# [06-26 20:10:42 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12500    e_greed:0.001   test_reward:-102.4
# [06-26 20:11:02 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12550    e_greed:0.001   test_reward:-102.8
# [06-26 20:11:21 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12600    e_greed:0.001   test_reward:-103.0
# [06-26 20:11:41 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12650    e_greed:0.001   test_reward:-102.4
# [06-26 20:12:01 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12700    e_greed:0.001   test_reward:-96.2
# [06-26 20:12:22 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12750    e_greed:0.001   test_reward:-90.2
# [06-26 20:12:41 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12800    e_greed:0.001   test_reward:-96.2
# [06-26 20:13:01 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12850    e_greed:0.001   test_reward:-97.0
# [06-26 20:13:20 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12900    e_greed:0.001   test_reward:-95.6
# [06-26 20:13:41 MainThread @<ipython-input-8-15532eada1ec>:37] episode:12950    e_greed:0.001   test_reward:-103.4
# [06-26 20:14:00 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13000    e_greed:0.001   test_reward:-99.8
# [06-26 20:14:20 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13050    e_greed:0.001   test_reward:-98.2
# [06-26 20:14:40 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13100    e_greed:0.001   test_reward:-115.8
# [06-26 20:15:01 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13150    e_greed:0.001   test_reward:-102.2
# [06-26 20:15:22 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13200    e_greed:0.001   test_reward:-106.0
# [06-26 20:15:43 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13250    e_greed:0.001   test_reward:-100.0
# [06-26 20:16:05 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13300    e_greed:0.001   test_reward:-96.4
# [06-26 20:16:25 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13350    e_greed:0.001   test_reward:-97.2
# [06-26 20:16:45 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13400    e_greed:0.001   test_reward:-102.2
# [06-26 20:17:06 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13450    e_greed:0.001   test_reward:-122.0
# [06-26 20:17:26 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13500    e_greed:0.001   test_reward:-99.8
# [06-26 20:17:45 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13550    e_greed:0.001   test_reward:-98.6
# [06-26 20:18:05 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13600    e_greed:0.001   test_reward:-92.8
# [06-26 20:18:24 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13650    e_greed:0.001   test_reward:-97.4
# [06-26 20:18:44 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13700    e_greed:0.001   test_reward:-99.6
# [06-26 20:19:03 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13750    e_greed:0.001   test_reward:-101.0
# [06-26 20:19:23 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13800    e_greed:0.001   test_reward:-103.4
# [06-26 20:19:42 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13850    e_greed:0.001   test_reward:-103.4
# [06-26 20:20:03 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13900    e_greed:0.001   test_reward:-97.6
# [06-26 20:20:23 MainThread @<ipython-input-8-15532eada1ec>:37] episode:13950    e_greed:0.001   test_reward:-96.4
# [06-26 20:20:43 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14000    e_greed:0.001   test_reward:-99.0
# [06-26 20:21:03 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14050    e_greed:0.001   test_reward:-104.2
# [06-26 20:21:22 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14100    e_greed:0.001   test_reward:-110.4
# [06-26 20:21:45 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14150    e_greed:0.001   test_reward:-127.4
# [06-26 20:22:06 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14200    e_greed:0.001   test_reward:-122.0
# [06-26 20:22:26 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14250    e_greed:0.001   test_reward:-99.6
# [06-26 20:22:45 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14300    e_greed:0.001   test_reward:-97.0
# [06-26 20:23:05 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14350    e_greed:0.001   test_reward:-95.8
# [06-26 20:23:25 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14400    e_greed:0.001   test_reward:-100.2
# [06-26 20:23:44 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14450    e_greed:0.001   test_reward:-96.6
# [06-26 20:24:04 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14500    e_greed:0.001   test_reward:-119.2
# [06-26 20:24:24 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14550    e_greed:0.001   test_reward:-122.4
# [06-26 20:24:45 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14600    e_greed:0.001   test_reward:-109.4
# [06-26 20:25:05 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14650    e_greed:0.001   test_reward:-104.0
# [06-26 20:25:25 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14700    e_greed:0.001   test_reward:-101.8
# [06-26 20:25:45 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14750    e_greed:0.001   test_reward:-109.6
# [06-26 20:26:04 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14800    e_greed:0.001   test_reward:-98.0
# [06-26 20:26:24 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14850    e_greed:0.001   test_reward:-101.8
# [06-26 20:26:44 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14900    e_greed:0.001   test_reward:-100.0
# [06-26 20:27:03 MainThread @<ipython-input-8-15532eada1ec>:37] episode:14950    e_greed:0.001   test_reward:-108.8
# [06-26 20:27:23 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15000    e_greed:0.001   test_reward:-95.8
# [06-26 20:27:43 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15050    e_greed:0.001   test_reward:-110.8
# [06-26 20:28:03 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15100    e_greed:0.001   test_reward:-97.6
# [06-26 20:28:23 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15150    e_greed:0.001   test_reward:-100.2
# [06-26 20:28:43 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15200    e_greed:0.001   test_reward:-99.6
# [06-26 20:29:02 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15250    e_greed:0.001   test_reward:-93.6
# [06-26 20:29:22 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15300    e_greed:0.001   test_reward:-94.8
# [06-26 20:29:42 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15350    e_greed:0.001   test_reward:-103.0
# [06-26 20:30:01 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15400    e_greed:0.001   test_reward:-98.6
# [06-26 20:30:20 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15450    e_greed:0.001   test_reward:-99.4
# [06-26 20:30:41 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15500    e_greed:0.001   test_reward:-101.4
# [06-26 20:31:01 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15550    e_greed:0.001   test_reward:-100.6
# [06-26 20:31:20 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15600    e_greed:0.001   test_reward:-100.2
# [06-26 20:31:40 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15650    e_greed:0.001   test_reward:-99.2
# [06-26 20:32:00 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15700    e_greed:0.001   test_reward:-98.2
# [06-26 20:32:19 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15750    e_greed:0.001   test_reward:-100.0
# [06-26 20:32:39 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15800    e_greed:0.001   test_reward:-102.2
# [06-26 20:32:58 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15850    e_greed:0.001   test_reward:-99.2
# [06-26 20:33:18 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15900    e_greed:0.001   test_reward:-94.8
# [06-26 20:33:40 MainThread @<ipython-input-8-15532eada1ec>:37] episode:15950    e_greed:0.001   test_reward:-119.6
# [06-26 20:34:01 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16000    e_greed:0.001   test_reward:-99.8
# [06-26 20:34:22 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16050    e_greed:0.001   test_reward:-108.6
# [06-26 20:34:42 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16100    e_greed:0.001   test_reward:-95.4
# [06-26 20:35:02 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16150    e_greed:0.001   test_reward:-97.0
# [06-26 20:35:22 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16200    e_greed:0.001   test_reward:-101.0
# [06-26 20:35:41 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16250    e_greed:0.001   test_reward:-104.2
# [06-26 20:36:01 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16300    e_greed:0.001   test_reward:-99.0
# [06-26 20:36:21 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16350    e_greed:0.001   test_reward:-100.0
# [06-26 20:36:41 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16400    e_greed:0.001   test_reward:-99.0
# [06-26 20:37:00 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16450    e_greed:0.001   test_reward:-92.4
# [06-26 20:37:20 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16500    e_greed:0.001   test_reward:-99.6
# [06-26 20:37:39 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16550    e_greed:0.001   test_reward:-95.2
# [06-26 20:37:59 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16600    e_greed:0.001   test_reward:-111.2
# [06-26 20:38:21 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16650    e_greed:0.001   test_reward:-103.2
# [06-26 20:38:42 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16700    e_greed:0.001   test_reward:-100.0
# [06-26 20:39:03 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16750    e_greed:0.001   test_reward:-101.0
# [06-26 20:39:24 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16800    e_greed:0.001   test_reward:-97.8
# [06-26 20:39:43 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16850    e_greed:0.001   test_reward:-96.0
# [06-26 20:40:02 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16900    e_greed:0.001   test_reward:-103.6
# [06-26 20:40:23 MainThread @<ipython-input-8-15532eada1ec>:37] episode:16950    e_greed:0.001   test_reward:-108.8
# [06-26 20:40:44 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17000    e_greed:0.001   test_reward:-104.4
# [06-26 20:41:04 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17050    e_greed:0.001   test_reward:-96.4
# [06-26 20:41:24 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17100    e_greed:0.001   test_reward:-87.4
# [06-26 20:41:44 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17150    e_greed:0.001   test_reward:-104.4
# [06-26 20:42:04 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17200    e_greed:0.001   test_reward:-97.2
# [06-26 20:42:24 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17250    e_greed:0.001   test_reward:-95.2
# [06-26 20:42:43 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17300    e_greed:0.001   test_reward:-100.2
# [06-26 20:43:02 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17350    e_greed:0.001   test_reward:-95.4
# [06-26 20:43:22 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17400    e_greed:0.001   test_reward:-88.4
# [06-26 20:43:41 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17450    e_greed:0.001   test_reward:-98.8
# [06-26 20:44:01 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17500    e_greed:0.001   test_reward:-106.6
# [06-26 20:44:22 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17550    e_greed:0.001   test_reward:-104.8
# [06-26 20:44:42 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17600    e_greed:0.001   test_reward:-101.2
# [06-26 20:45:03 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17650    e_greed:0.001   test_reward:-100.0
# [06-26 20:45:23 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17700    e_greed:0.001   test_reward:-93.4
# [06-26 20:45:42 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17750    e_greed:0.001   test_reward:-104.2
# [06-26 20:46:02 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17800    e_greed:0.001   test_reward:-102.0
# [06-26 20:46:22 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17850    e_greed:0.001   test_reward:-101.4
# [06-26 20:46:42 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17900    e_greed:0.001   test_reward:-98.8
# [06-26 20:47:03 MainThread @<ipython-input-8-15532eada1ec>:37] episode:17950    e_greed:0.001   test_reward:-105.2
# [06-26 20:47:24 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18000    e_greed:0.001   test_reward:-120.6
# [06-26 20:47:45 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18050    e_greed:0.001   test_reward:-98.8
# [06-26 20:48:05 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18100    e_greed:0.001   test_reward:-96.4
# [06-26 20:48:25 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18150    e_greed:0.001   test_reward:-91.6
# [06-26 20:48:46 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18200    e_greed:0.001   test_reward:-103.6
# [06-26 20:49:05 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18250    e_greed:0.001   test_reward:-97.8
# [06-26 20:49:26 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18300    e_greed:0.001   test_reward:-103.8
# [06-26 20:49:45 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18350    e_greed:0.001   test_reward:-100.6
# [06-26 20:50:05 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18400    e_greed:0.001   test_reward:-103.8
# [06-26 20:50:24 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18450    e_greed:0.001   test_reward:-98.4
# [06-26 20:50:44 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18500    e_greed:0.001   test_reward:-92.6
# [06-26 20:51:05 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18550    e_greed:0.001   test_reward:-99.2
# [06-26 20:51:25 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18600    e_greed:0.001   test_reward:-97.2
# [06-26 20:51:46 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18650    e_greed:0.001   test_reward:-101.8
# [06-26 20:52:07 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18700    e_greed:0.001   test_reward:-100.6
# [06-26 20:52:27 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18750    e_greed:0.001   test_reward:-93.2
# [06-26 20:52:47 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18800    e_greed:0.001   test_reward:-97.6
# [06-26 20:53:08 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18850    e_greed:0.001   test_reward:-102.6
# [06-26 20:53:28 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18900    e_greed:0.001   test_reward:-110.2
# [06-26 20:53:48 MainThread @<ipython-input-8-15532eada1ec>:37] episode:18950    e_greed:0.001   test_reward:-94.8
# [06-26 20:54:08 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19000    e_greed:0.001   test_reward:-106.0
# [06-26 20:54:28 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19050    e_greed:0.001   test_reward:-100.0
# [06-26 20:54:48 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19100    e_greed:0.001   test_reward:-96.2
# [06-26 20:55:07 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19150    e_greed:0.001   test_reward:-95.2
# [06-26 20:55:28 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19200    e_greed:0.001   test_reward:-97.4
# [06-26 20:55:48 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19250    e_greed:0.001   test_reward:-96.6
# [06-26 20:56:09 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19300    e_greed:0.001   test_reward:-103.0
# [06-26 20:56:30 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19350    e_greed:0.001   test_reward:-97.8
# [06-26 20:56:50 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19400    e_greed:0.001   test_reward:-97.4
# [06-26 20:57:10 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19450    e_greed:0.001   test_reward:-95.8
# [06-26 20:57:29 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19500    e_greed:0.001   test_reward:-100.0
# [06-26 20:57:49 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19550    e_greed:0.001   test_reward:-96.8
# [06-26 20:58:09 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19600    e_greed:0.001   test_reward:-102.4
# [06-26 20:58:29 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19650    e_greed:0.001   test_reward:-96.0
# [06-26 20:58:49 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19700    e_greed:0.001   test_reward:-115.8
# [06-26 20:59:09 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19750    e_greed:0.001   test_reward:-101.4
# [06-26 20:59:30 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19800    e_greed:0.001   test_reward:-102.8
# [06-26 20:59:49 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19850    e_greed:0.001   test_reward:-98.6
# [06-26 21:00:09 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19900    e_greed:0.001   test_reward:-100.2
# [06-26 21:00:29 MainThread @<ipython-input-8-15532eada1ec>:37] episode:19950    e_greed:0.001   test_reward:-100.0
# [06-26 21:00:49 MainThread @<ipython-input-8-15532eada1ec>:37] episode:20000    e_greed:0.001   test_reward:-104.2
